# %%
?write_csv
# Out:
# write_delim               package:readr                R Documentation
#
# e
#
# n:
#
#      The write_*() family of functions are an improvement to analogous
#      function such as ‘write.csv()’ because they are approximately
#      twice as fast. Unlike ‘write.csv()’, these functions do not
#      include row names as a column in the written file. A generic
#      function, ‘output_column()’, is applied to each variable to coerce
#      columns to suitable output.
#
# e:
#
#      write_delim(
#        x,
#        file,
#        delim = " ",
#        na = "NA",
#        append = FALSE,
#        col_names = !append,
#        quote = c("needed", "all", "none"),
#        escape = c("double", "backslash", "none"),
#        eol = "\n",
#        num_threads = readr_threads(),
#        progress = show_progress(),
#        path = deprecated(),
#        quote_escape = deprecated()
#      )
#
#      write_csv(
#        x,
#        file,
#        na = "NA",
#        append = FALSE,
# ...

# %%
library(tidyverse)
library(dplyr)

# %%
growth_data = read_csv("GrowthStatus Dataset.csv") 
colnames(growth_data) <- c('Age (Months)','Sex','Height (cm)', 'Nutritional_Status')
write_csv(growth_data,"GrowthStatus Dataset.csv")
# Out:
# Rows: 120999 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): Gender, Nutritional status
# dbl (2): Age (Month), Height (cm)
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
growth_data_female = growth_data |>
                        filter(Sex == "Female")

growth_data_female

write_csv(growth_data_female,"GrowthStatusFemale Dataset.csv")
# Out:
#       Age (Months) Sex    Height (cm) Nutritional_Status
# 1     0            Female 42.19578    severely stunted
# 2     0            Female 54.81734    Tall
# 3     0            Female 43.70211    stunted
# 4     0            Female 41.40035    severely stunted
# 5     0            Female 40.74822    severely stunted
# 6     0            Female 57.12486    Tall
# 7     0            Female 43.29577    severely stunted
# 8     0            Female 50.94519    normal
# 9     0            Female 40.85671    severely stunted
# 10    0            Female 48.69192    normal
# 11    0            Female 41.67847    severely stunted
# 12    0            Female 57.45645    Tall
# 13    0            Female 40.23594    severely stunted
# 14    0            Female 52.18537    normal
# 15    0            Female 58.78494    Tall
# 16    0            Female 42.46339    severely stunted
# 17    0            Female 51.34051    normal
# 18    0            Female 53.84272    normal
# ...
